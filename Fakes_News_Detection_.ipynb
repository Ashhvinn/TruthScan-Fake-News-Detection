# %%
# %load_ext autoreload
# %autoreload 2

# %%
#UV News Data Input
import pandas as pd
import numpy as np

true_path = 'True.csv'
fake_path = 'Fake.csv'

true_df = pd.read_csv(true_path)
fake_df = pd.read_csv(fake_path)

# %%
display(true_df)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...     worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...     worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...     worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...     worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...     worldnews
#
#                      date
# 0      December 31, 2017
# 1      December 29, 2017
# 2      December 31, 2017
# 3      December 30, 2017
# 4      December 29, 2017
# ...                   ...
# 21412    August 22, 2017
# 21413    August 22, 2017
# 21414    August 22, 2017
# 21415    August 22, 2017
# 21416    August 22, 2017
#
# [21417 rows x 4 columns]

# %%
display(fake_df)
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# 2      On Friday, it was revealed that former Milwauk...         News
# 3      On Christmas day, Donald Trump announced that ...         News
# 4      Pope Francis used his annual Christmas Day mes...         News
# ...                                                  ...          ...
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                     date
# 0      December 31, 2017
# 1      December 31, 2017
# 2      December 30, 2017
# 3      December 29, 2017
# 4      December 25, 2017
# ...                  ...
# 23476   January 16, 2016
# 23477   January 16, 2016
# 23478   January 15, 2016
# 23479   January 14, 2016
# 23480   January 12, 2016
#
# [23481 rows x 4 columns]

# %%
#Data Visulization
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(y="subject", palette="coolwarm", data=true_df).set_title('True News Subject Distribution')
plt.show()

sns.countplot(y="subject", palette="coolwarm", data=fake_df).set_title('Fake News Subject Distribution')
plt.show()
# Out:
# <ipython-input-12-cc6881c31812>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="subject", palette="coolwarm", data=true_df).set_title('True News Subject Distribution')
# <ipython-input-12-cc6881c31812>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="subject", palette="coolwarm", data=fake_df).set_title('Fake News Subject Distribution')

# %%
#Data Preprocessing

# %%
#Data Combination
# Add Labels to both df
true_df['true'] = 1
fake_df['true'] = 0

# Concat
df = pd.concat([true_df, fake_df])
display(df)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 23476  21st Century Wire says As 21WIRE reported earl...   Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...   Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...   Middle-east
# 23479  21st Century Wire says Al Jazeera America will...   Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...   Middle-east
#
#                      date  true
# 0      December 31, 2017      1
# 1      December 29, 2017      1
# 2      December 31, 2017      1
# 3      December 30, 2017      1
# 4      December 29, 2017      1
# ...                   ...   ...
# 23476    January 16, 2016     0
# 23477    January 16, 2016     0
# 23478    January 15, 2016     0
# 23479    January 14, 2016     0
# 23480    January 12, 2016     0
#
# [44898 rows x 5 columns]

# %% [markdown]
# ## Inspect Lengths of News

# %%
titles = [text for text in df.title]

max_len = 0
titles_len = []
for title in titles:
    titles_len.append(len(title.split()))
    max_len = max(len(title.split()), max_len)

print('Number of titles:', len(titles))
print('Max length of the titles:', max_len)
print('Mean length of the titles:', np.mean(titles_len))
# Out:
# Number of titles: 44898
# Max length of the titles: 42
# Mean length of the titles: 12.453472315025168

# %%
texts = [text for text in df.text]

max_len = 0
texts_len = []
for text in texts:
    texts_len.append(len(text.split()))
    max_len = max(len(text.split()), max_len)

# g = sns.countplot(x=texts_len)
print('Mean length of the texts:', np.mean(texts_len))
# Out:
# Mean length of the texts: 405.28228428883244

# %% [markdown]
# ## Purify & Shffle the DataFrame

# %%
from sklearn.utils import shuffle

# Purify
df = df.iloc[:,[0, -1]]

# Shuffle
df = shuffle(df).reset_index(drop=True)

display(df)
# Out:
#                                                    title  true
# 0      DEMOCRAT HEADS SET TO EXPLODE: Feds Waive Envi...     0
# 1        Swiss strip refugee status from Libyan preacher     1
# 2      Fear driving Cambodian opposition MPs abroad, ...     1
# 3       Planned Parenthood’s Latest Announcement Will...     0
# 4      LOL! Black Conservative DESTROYS “Current Day ...     0
# ...                                                  ...   ...
# 44893  TRUMP-HATING, Anti-Gun “COMEDIAN” And Author O...     0
# 44894  WOW! DONNA BRAZILE Tells Critics Of Her Book O...     0
# 44895   Trump Just Got Caught Trying To Blackmail Mor...     0
# 44896  Senator Markey wants government informed of av...     1
# 44897  Nigeria replaces commander in fight against Bo...     1
#
# [44898 rows x 2 columns]

# %% [markdown]
# ## Split Data into Training, Validation, Test

# %%
train_val_df = df.sample(frac = 0.8)
test_df = df.drop(train_val_df.index)

train_df = train_val_df.sample(frac = 0.8)
val_df = train_val_df.drop(train_df.index)

# Reset Index
train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

print('trainset size:', train_df.shape)
print('valset size:', val_df.shape)
print('testset size:', test_df.shape)
# Out:
# trainset size: (28734, 2)
# valset size: (7184, 2)
# testset size: (8980, 2)

# %% [markdown]
# ## Data distribution imbalanced

# %%
# train_imbalanced = 1/10
# val_imbalanced = 1/10
# test_imbalanced = 1/10

# train_true = train_df[train_df['true'] == 1]
# train_fake = train_df[train_df['true'] == 0]
# train_fake = train_fake.iloc[:round(len(train_fake)*train_imbalanced),:]
# train_true_len = len(train_true)
# train_fake_len = len(train_fake)
# train_df = pd.concat([train_true, train_fake])

# val_true = val_df[val_df['true'] == 1]
# val_fake = val_df[val_df['true'] == 0]
# val_fake = val_fake.iloc[:round(len(val_fake)*val_imbalanced),:]
# val_true_len = len(val_true)
# val_fake_len = len(val_fake)
# val_df = pd.concat([val_true, val_fake])

# test_true = test_df[test_df['true'] == 1]
# test_fake = test_df[test_df['true'] == 0]
# test_fake = test_fake.iloc[:round(len(test_fake)*test_imbalanced),:]
# test_true_len = len(test_true)
# test_fake_len = len(test_fake)
# test_df = pd.concat([test_true, test_fake])

# len_df = pd.DataFrame({'ind': ['Train', 'Validation', 'Test'], 'True': [train_true_len, val_true_len, test_true_len], 'Fake': [train_fake_len, val_fake_len, test_fake_len]})
# len_df.set_index('ind', inplace=True)
# len_df.index.name = None

# len_df

# %% [markdown]
# ## Dataframe to csv

# %%
train_df.to_csv('train.tsv', sep='\t', index=False)
val_df.to_csv('val.tsv', sep='\t', index=False)
test_df.to_csv('test.tsv', sep='\t', index=False)

# %%
#Concatenate all dataframe
df = pd.concat([train_df, val_df, test_df])
df
# Out:
#                                                   title  true
# 0     “BLOOD ON THEIR HANDS” FOR VOTING RIGHTS: The ...     0
# 1     GARY JOHNSON IS A COMPLETE IDIOT….And Here’s W...     0
# 2     BILL CLINTON’S 12-YR Mistress Gennifer Flowers...     0
# 3     Aide to EU Commission head tweets picture of w...     1
# 4     “Would You Rather Do A Job You Hate And Not Pa...     0
# ...                                                 ...   ...
# 8975   Ted Cruz Tells Megyn Kelly He Would Force Rap...     0
# 8976  BREAKING NEWS: Vladimir Putin Retaliates After...     0
# 8977  Criticized for Egypt ties, France to raise hum...     1
# 8978   Watch: Joe Biden Just Wrecked Trump In Six Wo...     0
# 8979  ESPN’S JEMELE HILL Makes Shocking Admission Ab...     0
#
# [44898 rows x 2 columns]

# %%
#Performing Data Cleaning
import nltk
# Downloading Stopwords
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Obtaining Additional Stopwords From nltk
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
# Removing Stopwords And Remove Words With 2 Or Less Characters
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3 and token not in stop_words:
            result.append(token)

    return result

# %%
import gensim

# Applying The Function To The Dataframe
df['clean'] = df['title'].apply(preprocess)

# %% [markdown]
# ## Obtaining The Total Words Present In The Dataset

# %%
list_of_words = []
for i in df.clean:
    for j in i:
        list_of_words.append(j)

total_words = len(list(set(list_of_words)))
total_words
# Out:
# 19174

# %% [markdown]
# ## Preparing The Data By Performing Tokenization And Padding

# %%
from nltk import word_tokenize

# %%
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer

# Creating A Tokenizer To Tokenize The Words And Create Sequences Of Tokenized Words
tokenizer = Tokenizer(num_words = total_words)
tokenizer.fit_on_texts(train_df['title'])

train_sequences = tokenizer.texts_to_sequences(train_df['title'])
val_sequences = tokenizer.texts_to_sequences(val_df['title'])
test_sequences = tokenizer.texts_to_sequences(test_df['title'])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Adding Padding
padded_train = pad_sequences(train_sequences,maxlen = 42, padding = 'post', truncating = 'post')
padded_val = pad_sequences(val_sequences,maxlen = 42, padding = 'post', truncating = 'post')
padded_test = pad_sequences(test_sequences,maxlen = 42, padding = 'post', truncating = 'post')

# %% [markdown]
# # LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Embedding, LSTM

# Set the vocabulary size for the embedding layer
total_words = 19174  # Replace with your vocabulary size
embedding_vector_features = 40  # Dimensionality of the embedding

# Creating the LSTM model
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=embedding_vector_features, input_length=20))
model.add(Dropout(0.3))
model.add(LSTM(100))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Force model to build by specifying input shape
model.build((None, 20))

# Display the summary to show parameter counts
print(model.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 20, 40)              │         766,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 20, 40)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 100)                 │          56,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 823,461 (3.14 MB)
#  Trainable params: 823,461 (3.14 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

# Assuming you have already loaded and preprocessed your data into train_df, val_df, and test_df

# Tokenizing and padding the sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_df['title'])

total_words = len(tokenizer.word_index) + 1  # Adding 1 because of reserved 0 index
max_sequence_length = 20

train_sequences = tokenizer.texts_to_sequences(train_df['title'])
val_sequences = tokenizer.texts_to_sequences(val_df['title'])
test_sequences = tokenizer.texts_to_sequences(test_df['title'])

padded_train = pad_sequences(train_sequences, maxlen=max_sequence_length, padding='post')
padded_val = pad_sequences(val_sequences, maxlen=max_sequence_length, padding='post')
padded_test = pad_sequences(test_sequences, maxlen=max_sequence_length, padding='post')

# Defining the LSTM model
embedding_dim = 40
model = Sequential([
    Embedding(input_dim=total_words, output_dim=embedding_dim, input_length=max_sequence_length),
    LSTM(100),
    Dense(1, activation='sigmoid')
])

# Compiling the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Printing model summary to verify the layers are built correctly
model.build(input_shape=(None, max_sequence_length))  # This forces model building with specified input shape
print(model.summary())

# Preparing labels for training and validation sets
y_train = np.asarray(train_df['true'])
y_val = np.asarray(val_df['true'])

# Training the model
history = model.fit(padded_train, y_train, batch_size=64, validation_data=(padded_val, y_val), epochs=30)

# Evaluation metrics on the validation set
val_predictions = model.predict(padded_val)
val_prediction_classes = (val_predictions > 0.5).astype("int32")
accuracy = accuracy_score(y_val, val_prediction_classes)
precision = precision_score(y_val, val_prediction_classes)
recall = recall_score(y_val, val_prediction_classes)
f1 = f1_score(y_val, val_prediction_classes)

# Print evaluation metrics
print("Validation Metrics:")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Plotting the evaluation metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
values = [accuracy, precision, recall, f1]

plt.figure(figsize=(6, 4))
plt.bar(metrics, values, color=['blue', 'green', 'orange', 'red'])
plt.title('Model Evaluation Metrics')
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.ylim(0, 1)  # Set y-axis limit from 0 to 1
plt.show()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 20, 40)              │       1,067,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100)                 │          56,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,124,261 (4.29 MB)
#  Trainable params: 1,124,261 (4.29 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8778 - loss: 0.2489 - val_accuracy: 0.9667 - val_loss: 0.0930
# Epoch 2/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9871 - loss: 0.0379 - val_accuracy: 0.9649 - val_loss: 0.0983
# Epoch 3/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9934 - loss: 0.0200 - val_accuracy: 0.9642 - val_loss: 0.1358
# Epoch 4/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9965 - loss: 0.0112 - val_accuracy: 0.9633 - val_loss: 0.1422
# Epoch 5/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9982 - loss: 0.0069 - val_accuracy: 0.9612 - val_loss: 0.1614
# Epoch 6/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9982 - loss: 0.0056 - val_accuracy: 0.9628 - val_loss: 0.1919
# Epoch 7/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9983 - loss: 0.0056 - val_accuracy: 0.9605 - val_loss: 0.1906
# Epoch 8/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9988 - loss: 0.0034 - val_accuracy: 0.9606 - val_loss: 0.2296
# Epoch 9/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9991 - loss: 0.0032 - val_accuracy: 0.9575 - val_loss: 0.1559
# Epoch 10/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9989 - loss: 0.0037 - val_accuracy: 0.9596 - val_loss: 0.2866
# Epoch 11/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.9518 - val_loss: 0.4033
# Epoch 12/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9979 - loss: 0.0068 - val_accuracy: 0.9609 - val_loss: 0.2157
# Epoch 13/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9998 - loss: 9.6472e-04 - val_accuracy: 0.9610 - val_loss: 0.2437
# Epoch 14/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9999 - loss: 2.8939e-04 - val_accuracy: 0.9603 - val_loss: 0.3159
# Epoch 15/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9999 - loss: 2.3885e-04 - val_accuracy: 0.9607 - val_loss: 0.2663
# Epoch 16/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9986 - loss: 0.0042 - val_accuracy: 0.9605 - val_loss: 0.2546
# Epoch 17/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9995 - loss: 0.0016 - val_accuracy: 0.9623 - val_loss: 0.2429
# Epoch 18/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9606 - val_loss: 0.2763
# Epoch 19/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9998 - loss: 5.0991e-04 - val_accuracy: 0.9594 - val_loss: 0.3257
# Epoch 20/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.9601 - val_loss: 0.2985
# Epoch 21/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9997 - loss: 7.3930e-04 - val_accuracy: 0.9566 - val_loss: 0.2650
# Epoch 22/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9999 - loss: 4.2341e-04 - val_accuracy: 0.9585 - val_loss: 0.1879
# Epoch 23/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.9619 - val_loss: 0.2374
# Epoch 24/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 1.0000 - loss: 8.4541e-05 - val_accuracy: 0.9617 - val_loss: 0.3105
# Epoch 25/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 1.0000 - loss: 3.0840e-05 - val_accuracy: 0.9607 - val_loss: 0.4002
# Epoch 26/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9994 - loss: 0.0016 - val_accuracy: 0.9582 - val_loss: 0.3219
# Epoch 27/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 7.5815e-05 - val_accuracy: 0.9568 - val_loss: 0.2829
# Epoch 28/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9992 - loss: 0.0025 - val_accuracy: 0.9607 - val_loss: 0.2512
# Epoch 29/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9997 - loss: 9.4839e-04 - val_accuracy: 0.9596 - val_loss: 0.2504
# Epoch 30/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 1.0000 - loss: 1.2363e-04 - val_accuracy: 0.9613 - val_loss: 0.3269
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Validation Metrics:
# Accuracy: 0.9613028953229399
# Precision: 0.9602962962962963
# Recall: 0.9574593796159527
# F1 Score: 0.9588757396449704

# %% [markdown]
# # Bidirectional LSTM

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

embedding_vector_features = 40
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=embedding_vector_features))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(100)))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# Compiling the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Printing model summary to verify the layers
model.build(input_shape=(None, max_sequence_length))
print(model.summary())
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_6 (Embedding)              │ (None, 20, 40)              │       1,067,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 20, 40)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 200)                 │         112,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 200)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             201 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,180,761 (4.50 MB)
#  Trainable params: 1,180,761 (4.50 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
y_train = np.asarray(train_df['true'])
y_val = np.asarray(val_df['true'])

# Training the model
model.fit(padded_train, y_train, batch_size = 64, validation_data=(padded_val, y_val), epochs = 30)
# Out:
# Epoch 1/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9010 - loss: 0.2484 - val_accuracy: 0.9641 - val_loss: 0.1133
# Epoch 2/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9858 - loss: 0.0414 - val_accuracy: 0.9683 - val_loss: 0.0920
# Epoch 3/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9940 - loss: 0.0183 - val_accuracy: 0.9681 - val_loss: 0.1178
# Epoch 4/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9968 - loss: 0.0118 - val_accuracy: 0.9688 - val_loss: 0.1141
# Epoch 5/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9980 - loss: 0.0068 - val_accuracy: 0.9658 - val_loss: 0.1517
# Epoch 6/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9983 - loss: 0.0059 - val_accuracy: 0.9658 - val_loss: 0.1410
# Epoch 7/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9982 - loss: 0.0057 - val_accuracy: 0.9674 - val_loss: 0.1552
# Epoch 8/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9987 - loss: 0.0041 - val_accuracy: 0.9645 - val_loss: 0.1565
# Epoch 9/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9994 - loss: 0.0023 - val_accuracy: 0.9674 - val_loss: 0.1487
# Epoch 10/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9988 - loss: 0.0030 - val_accuracy: 0.9627 - val_loss: 0.2366
# Epoch 11/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9990 - loss: 0.0040 - val_accuracy: 0.9683 - val_loss: 0.1480
# Epoch 12/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9995 - loss: 0.0023 - val_accuracy: 0.9648 - val_loss: 0.1623
# Epoch 13/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9990 - loss: 0.0023 - val_accuracy: 0.9665 - val_loss: 0.1506
# Epoch 14/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9683 - val_loss: 0.1914
# Epoch 15/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9993 - loss: 0.0018 - val_accuracy: 0.9699 - val_loss: 0.1496
# Epoch 16/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9992 - loss: 0.0026 - val_accuracy: 0.9666 - val_loss: 0.1937
# Epoch 17/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9684 - val_loss: 0.1626
# Epoch 18/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9993 - loss: 0.0016 - val_accuracy: 0.9680 - val_loss: 0.1810
# Epoch 19/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9997 - loss: 8.9430e-04 - val_accuracy: 0.9669 - val_loss: 0.1794
# Epoch 20/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9998 - loss: 5.9098e-04 - val_accuracy: 0.9630 - val_loss: 0.2128
# Epoch 21/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9656 - val_loss: 0.1560
# Epoch 22/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9999 - loss: 3.7066e-04 - val_accuracy: 0.9656 - val_loss: 0.2414
# Epoch 23/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.9631 - val_loss: 0.2186
# Epoch 24/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9997 - loss: 8.3609e-04 - val_accuracy: 0.9655 - val_loss: 0.1929
# Epoch 25/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9998 - loss: 5.7784e-04 - val_accuracy: 0.9658 - val_loss: 0.2183
# Epoch 26/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 1.0000 - loss: 6.7160e-05 - val_accuracy: 0.9666 - val_loss: 0.2324
# Epoch 27/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9997 - loss: 8.3910e-04 - val_accuracy: 0.9633 - val_loss: 0.2391
# Epoch 28/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9999 - loss: 6.2704e-04 - val_accuracy: 0.9631 - val_loss: 0.2865
# Epoch 29/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9994 - loss: 0.0017 - val_accuracy: 0.9677 - val_loss: 0.1842
# Epoch 30/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 1.0000 - loss: 1.7893e-04 - val_accuracy: 0.9645 - val_loss: 0.2219

# %% [markdown]
# ## Assessing Trained Model Performance

# %%
# Evaluation metrics
val_predictions = model.predict(padded_val)
val_prediction_classes = (val_predictions > 0.5).astype("int32")
accuracy = accuracy_score(y_val, val_prediction_classes)
precision = precision_score(y_val, val_prediction_classes)
recall = recall_score(y_val, val_prediction_classes)
f1 = f1_score(y_val, val_prediction_classes)

# Print evaluation metrics
print("Validation Metrics of BI-LSTM Model are:")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Plotting bar graph
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
values = [accuracy, precision, recall, f1]

plt.figure(figsize=(4, 3))
plt.bar(metrics, values, color=['blue', 'green', 'orange', 'red'])
plt.title('Model Evaluation Metrics')
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.ylim(0, 1)  # Set y-axis limit from 0 to 1
plt.show()
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Validation Metrics of BI-LSTM Model are:
# Accuracy: 0.9645044543429844
# Precision: 0.956534422403734
# Recall: 0.968685376661743
# F1 Score: 0.9625715543813298

# %% [markdown]
# # CNN-BiLSTM

# %%
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional, Conv1D, MaxPooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

# Assuming you have already loaded and preprocessed your data into train_df, val_df, and test_df

# Tokenizing and padding the sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_df['title'])

total_words = len(tokenizer.word_index) + 1  # Adding 1 because of reserved 0 index
max_sequence_length = 20

train_sequences = tokenizer.texts_to_sequences(train_df['title'])
val_sequences = tokenizer.texts_to_sequences(val_df['title'])
test_sequences = tokenizer.texts_to_sequences(test_df['title'])

padded_train = pad_sequences(train_sequences, maxlen=max_sequence_length, padding='post')
padded_val = pad_sequences(val_sequences, maxlen=max_sequence_length, padding='post')
padded_test = pad_sequences(test_sequences, maxlen=max_sequence_length, padding='post')

# Defining the CNN-LSTM model
embedding_vector_features = 40
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=embedding_vector_features))
model.add(Dropout(0.3))
model.add(Conv1D(32, 5, activation='relu'))
model.add(MaxPooling1D())
model.add(Bidirectional(LSTM(100)))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# Compiling the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Printing model summary to verify the layers
model.build(input_shape=(None, max_sequence_length))
print(model.summary())
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_9 (Embedding)              │ (None, 20, 40)              │       1,067,760 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 20, 40)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 16, 32)              │           6,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 8, 32)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 200)                 │         106,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 200)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             201 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,180,793 (4.50 MB)
#  Trainable params: 1,180,793 (4.50 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
y_train = np.asarray(train_df['true'])
y_val = np.asarray(val_df['true'])

# Training the model
model.fit(padded_train, y_train, batch_size = 64, validation_data=(padded_val, y_val), epochs = 30)
# Out:
# Epoch 1/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8940 - loss: 0.2655 - val_accuracy: 0.9684 - val_loss: 0.0887
# Epoch 2/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9855 - loss: 0.0424 - val_accuracy: 0.9712 - val_loss: 0.0824
# Epoch 3/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9956 - loss: 0.0151 - val_accuracy: 0.9671 - val_loss: 0.1120
# Epoch 4/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9979 - loss: 0.0061 - val_accuracy: 0.9683 - val_loss: 0.1173
# Epoch 5/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9982 - loss: 0.0053 - val_accuracy: 0.9676 - val_loss: 0.1480
# Epoch 6/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9989 - loss: 0.0036 - val_accuracy: 0.9660 - val_loss: 0.1378
# Epoch 7/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9994 - loss: 0.0027 - val_accuracy: 0.9663 - val_loss: 0.1653
# Epoch 8/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.9684 - val_loss: 0.1555
# Epoch 9/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9993 - loss: 0.0017 - val_accuracy: 0.9678 - val_loss: 0.1883
# Epoch 10/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9982 - loss: 0.0049 - val_accuracy: 0.9670 - val_loss: 0.1943
# Epoch 11/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9994 - loss: 0.0015 - val_accuracy: 0.9673 - val_loss: 0.1674
# Epoch 12/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9996 - loss: 0.0011 - val_accuracy: 0.9688 - val_loss: 0.2372
# Epoch 13/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.9674 - val_loss: 0.1705
# Epoch 14/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9998 - loss: 0.0014 - val_accuracy: 0.9669 - val_loss: 0.1616
# Epoch 15/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9997 - loss: 9.7542e-04 - val_accuracy: 0.9663 - val_loss: 0.2297
# Epoch 16/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9998 - loss: 7.6729e-04 - val_accuracy: 0.9649 - val_loss: 0.1869
# Epoch 17/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 0.9677 - val_loss: 0.1945
# Epoch 18/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9999 - loss: 5.8868e-04 - val_accuracy: 0.9692 - val_loss: 0.2215
# Epoch 19/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9992 - loss: 0.0022 - val_accuracy: 0.9648 - val_loss: 0.1890
# Epoch 20/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9998 - loss: 5.5354e-04 - val_accuracy: 0.9651 - val_loss: 0.2008
# Epoch 21/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9998 - loss: 4.9143e-04 - val_accuracy: 0.9660 - val_loss: 0.1871
# Epoch 22/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 1.0000 - loss: 1.3204e-04 - val_accuracy: 0.9660 - val_loss: 0.2621
# Epoch 23/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 0.9655 - val_loss: 0.2149
# Epoch 24/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9998 - loss: 4.7488e-04 - val_accuracy: 0.9663 - val_loss: 0.2335
# Epoch 25/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9997 - loss: 8.9253e-04 - val_accuracy: 0.9635 - val_loss: 0.1657
# Epoch 26/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 1.0000 - loss: 3.3490e-04 - val_accuracy: 0.9655 - val_loss: 0.2618
# Epoch 27/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 1.0000 - loss: 1.3138e-04 - val_accuracy: 0.9653 - val_loss: 0.2565
# Epoch 28/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9663 - val_loss: 0.1917
# Epoch 29/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9999 - loss: 3.7914e-04 - val_accuracy: 0.9641 - val_loss: 0.2518
# Epoch 30/30
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9999 - loss: 5.1924e-04 - val_accuracy: 0.9674 - val_loss: 0.2083

# %% [markdown]
# ## Assessing Trained Model Performance

# %%
# Evaluation metrics
val_predictions = model.predict(padded_val)
val_prediction_classes = (val_predictions > 0.5).astype("int32")
accuracy = accuracy_score(y_val, val_prediction_classes)
precision = precision_score(y_val, val_prediction_classes)
recall = recall_score(y_val, val_prediction_classes)
f1 = f1_score(y_val, val_prediction_classes)

# Print evaluation metrics
print("Validation Metrics of CNN are :")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Plotting bar graph
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
values = [accuracy, precision, recall, f1]

plt.figure(figsize=(4, 3))
plt.bar(metrics, values, color=['blue', 'green', 'orange', 'red'])
plt.title('Model Evaluation Metrics')
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.ylim(0, 1)  # Set y-axis limit from 0 to 1
plt.show()
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Validation Metrics of CNN are :
# Accuracy: 0.9674276169265034
# Precision: 0.9618880093814131
# Recall: 0.9692762186115215
# F1 Score: 0.9655679811653914

# %% [markdown]
# # BERT

# %%
# !pip install transformers

import torch
from transformers import BertTokenizer
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)

# %%
PRETRAINED_MODEL_NAME = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(PRETRAINED_MODEL_NAME)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# ## Load Dataset Class

# %%
from torch.utils.data import Dataset

class FakeNewsDataset(Dataset):
    def __init__(self, mode, tokenizer):
        assert mode in ['train', 'val', 'test']
        self.mode = mode
        self.df = pd.read_csv(mode + '.tsv', sep='\t').fillna("")
        self.len = len(self.df)
        self.tokenizer = tokenizer

    def __getitem__(self, idx):
        if self.mode == 'test':
            statement, label = self.df.iloc[idx, :].values
            label_tensor = torch.tensor(label)
        else:
            statement, label = self.df.iloc[idx, :].values
            label_tensor = torch.tensor(label)
        word_pieces = ['[CLS]']
        statement = self.tokenizer.tokenize(statement)
        word_pieces += statement + ['[SEP]']
        len_st = len(word_pieces)

        ids = self.tokenizer.convert_tokens_to_ids(word_pieces)
        tokens_tensor = torch.tensor(ids)

        segments_tensor = torch.tensor([0] * len_st, dtype=torch.long)

        return (tokens_tensor, segments_tensor, label_tensor)

    def __len__(self):
        return self.len


# Initialize Datasets for Transformation
trainset = FakeNewsDataset('train', tokenizer=tokenizer)
valset = FakeNewsDataset('val', tokenizer=tokenizer)
testset = FakeNewsDataset('test', tokenizer=tokenizer)

print('trainset size:' ,trainset.__len__())
print('valset size:',valset.__len__())
print('testset size: ',testset.__len__())
# Out:
# trainset size: 28734
# valset size: 7184
# testset size:  8980

# %% [markdown]
# ## Reforming the Dataset to Fit the Model

# %%
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
def create_mini_batch(samples):
    tokens_tensors = [s[0] for s in samples]
    segments_tensors = [s[1] for s in samples]

    if samples[0][2] is not None:
        label_ids = torch.stack([s[2] for s in samples])
    else:
        label_ids = None

    # Zero Padding
    tokens_tensors = pad_sequence(tokens_tensors, batch_first=True)
    segments_tensors = pad_sequence(segments_tensors, batch_first=True)

    masks_tensors = torch.zeros(tokens_tensors.shape, dtype=torch.long)
    masks_tensors = masks_tensors.masked_fill(tokens_tensors != 0, 1)

    return tokens_tensors, segments_tensors, masks_tensors, label_ids

BATCH_SIZE = 16
trainloader = DataLoader(trainset, batch_size=BATCH_SIZE, collate_fn=create_mini_batch)
valloader = DataLoader(valset, batch_size=BATCH_SIZE, collate_fn=create_mini_batch)
testloader = DataLoader(testset, batch_size=BATCH_SIZE,collate_fn=create_mini_batch)

# %% [markdown]
# ## Model Construction

# %%
from transformers import BertForSequenceClassification
from IPython.display import display, clear_output

PRETRAINED_MODEL_NAME = "bert-base-uncased"
NUM_LABELS = 2

model = BertForSequenceClassification.from_pretrained(
    PRETRAINED_MODEL_NAME, num_labels=NUM_LABELS)

clear_output()

print("""
name             module
-----------------------""")
for name, module in model.named_children():
    if name == "bert":
        for n, _ in module.named_children():
            print(f"{name}:{n}")
    else:
        print("{:16} {}".format(name, module))
# Out:
# name             module
# -----------------------
# bert:embeddings
# bert:encoder
# bert:pooler
# dropout          Dropout(p=0.1, inplace=False)
# classifier       Linear(in_features=768, out_features=2, bias=True)

# %% [markdown]
# # Fine-Tuning of BERT

# %%
import torch
from sklearn.metrics import accuracy_score
from tqdm.notebook import tqdm
from transformers import BertForSequenceClassification

# ... (Rest of your imports and code)

# Check the number of available GPUs and select accordingly
num_gpus = torch.cuda.device_count()
if num_gpus > 0:
    # If more than one GPU, use the second one (index 1), otherwise use the first (index 0)
    device_index = 1 if num_gpus > 1 else 0
    device = torch.device(f"cuda:{device_index}")
else:
    device = torch.device("cpu")

print("device:", device)
model = model.to(device)
model.train()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)
NUM_EPOCHS = 10

for epoch in range(NUM_EPOCHS):
    train_loss = 0.0
    train_acc = 0.0

    loop = tqdm(trainloader)
    for batch_idx, data in enumerate(loop):
        tokens_tensors, segments_tensors, masks_tensors, labels = [t.to(device) for t in data]
        optimizer.zero_grad()

        outputs = model(input_ids=tokens_tensors,
                        token_type_ids=segments_tensors,
                        attention_mask=masks_tensors,
                        labels=labels)

        loss = outputs[0]
        loss.backward()
        optimizer.step()

        logits = outputs[1]
        _, pred = torch.max(logits.data, 1)
        train_acc = accuracy_score(pred.cpu().tolist() , labels.cpu().tolist())

        train_loss += loss.item()

        loop.set_description(f"Epoch [{epoch+1}/{NUM_EPOCHS}]")
        loop.set_postfix(acc = train_acc, loss = train_loss)
# Out:
# device: cuda:0
#   0%|          | 0/1796 [00:00<?, ?it/s]
#   0%|          | 0/1796 [00:00<?, ?it/s]
#   0%|          | 0/1796 [00:00<?, ?it/s]
#   0%|          | 0/1796 [00:00<?, ?it/s]
#   0%|          | 0/1796 [00:00<?, ?it/s]
#   0%|          | 0/1796 [00:00<?, ?it/s]
#   0%|          | 0/1796 [00:00<?, ?it/s]
#   0%|          | 0/1796 [00:00<?, ?it/s]
#   0%|          | 0/1796 [00:00<?, ?it/s]
#   0%|          | 0/1796 [00:00<?, ?it/s]

# %% [markdown]
# ## Save Model

# %%
torch.save(model, './best_model.pth')
print('Model saved!')
# Out:
# Model saved!

# %% [markdown]
# ## Load Model

# %%
# model = torch.load('./best_model.pth')
# model = model.to(device)

# %% [markdown]
# # Test

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

true=[]
predictions=[]
with torch.no_grad():
    model.eval()
    for data in testloader:
        if next(model.parameters()).is_cuda:
            data = [t.to(device) for t in data if t is not None]

        tokens_tensors, segments_tensors, masks_tensors = data[:3]
        test_outputs = model(input_ids=tokens_tensors,
                    token_type_ids=segments_tensors,
                    attention_mask=masks_tensors)

        logits = test_outputs[0]
        _, pred = torch.max(logits.data, 1)

        labels = data[3]
        true.extend(labels.cpu().tolist())
        predictions.extend(pred.cpu().tolist())


cm = confusion_matrix(true, predictions, labels=[1, 0], normalize='pred')
print(cm)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Real', 'Fake'])
disp.plot()

print('Acc: ', accuracy_score(predictions,true))
# Out:
# [[0.98951049 0.01236674]
#  [0.01048951 0.98763326]]
# Acc:  0.9885300668151448

# %%
df = pd.DataFrame({"pred_label": predictions})

df_pred = pd.concat([testset.df.loc[:, ['title']],
                          testset.df.loc[:, ['true']],
                          df.loc[:, 'pred_label']], axis=1)
# df_pred.to_csv('bert_1_prec_training_samples.csv', index=False)
df_pred
# Out:
#                                                   title  true  pred_label
# 0     TRUMP INSIDER REVEALS Donald’s Top Pick For VP...     0           0
# 1     If threatened, U.S. will 'totally destroy' Nor...     1           1
# 2     First charges filed in Russia probe led by U.S...     1           1
# 3     PRIORITIES: AS VETS LAY DYING, WAITING For Med...     0           0
# 4     United States, China to meet on North Korea on...     1           1
# ...                                                 ...   ...         ...
# 8975   Ted Cruz Tells Megyn Kelly He Would Force Rap...     0           0
# 8976  BREAKING NEWS: Vladimir Putin Retaliates After...     0           0
# 8977  Criticized for Egypt ties, France to raise hum...     1           1
# 8978   Watch: Joe Biden Just Wrecked Trump In Six Wo...     0           0
# 8979  ESPN’S JEMELE HILL Makes Shocking Admission Ab...     0           0
#
# [8980 rows x 3 columns]

# %%
print(classification_report(df_pred.true, df_pred.pred_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4677
#            1       0.99      0.99      0.99      4303
#
#     accuracy                           0.99      8980
#    macro avg       0.99      0.99      0.99      8980
# weighted avg       0.99      0.99      0.99      8980
